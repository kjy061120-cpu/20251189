# %%
# -------------------------
# Node
# -------------------------
class BidirectNode:
    def __init__(self, item, prev, next):
        self.item = item
        self.prev = prev
        self.next = next


# -------------------------
# List
# -------------------------
class CircularDoublyLinkedList:
    def __init__(self):
        self.__head = BidirectNode("dummy", None, None)
        self.__head.prev = self.__head
        self.__head.next = self.__head
        self.__numItems = 0

    def append(self, item):
        prev = self.__head.prev
        newNode = BidirectNode(item, prev, self.__head)
        prev.next = newNode
        self.__head.prev = newNode
        self.__numItems += 1

    def size(self):
        return self.__numItems

    def get(self, i):
        curr = self.__head.next
        for _ in range(i):
            curr = curr.next
        return curr.item


# -------------------------
# 실행 코드
# -------------------------
cdll = CircularDoublyLinkedList()


cdll.append(("이채윤", "2005-08-21", "2조"))
cdll.append(("구수진", "2005-04-08", "2조"))
cdll.append(("권지영", "2003-02-05", "2조"))
cdll.append(("김수민", "2006-07-09", "2조"))
cdll.append(("김주영", "2006-11-20", "2조"))
cdll.append(("김태연", "2006-03-22", "2조"))
cdll.append(("김효린", "2006-12-16", "2조"))
cdll.append(("서지윤", "2005-09-22", "2조"))
cdll.append(("이승주", "2006-03-26", "2조"))
cdll.append(("이시현", "2006-01-25", "3조"))
cdll.append(("안서영", "2004-06-21", "1조"))
cdll.append(("김승현", "2003-03-11", "1조"))
cdll.append(("이예지", "2005-01-04", "3조"))
cdll.append(("조은서", "2005-07-19", "3조"))
cdll.append(("황다원", "2004-10-15", "4조"))
cdll.append(("장채은", "2005-05-08", "3조"))
cdll.append(("최윤지", "2006-08-30", "3조"))
cdll.append(("이하연", "2006-09-22", "4조"))

for i in range(cdll.size()):
    item = cdll.get(i)

    name, birth, group = item  # ⭐ 여기 들어감

    if group == "2조":
        print(name)
